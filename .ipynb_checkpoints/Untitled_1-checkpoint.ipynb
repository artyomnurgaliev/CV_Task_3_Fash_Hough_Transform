# %%
! pip install pillow
! pip install numpy
! pip install matplotlib
! pip install scipy
# Out:
# Requirement already satisfied: pillow in c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\lib\site-packages (8.4.0)
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: numpy in c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\lib\site-packages (1.21.3)
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: matplotlib in c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\lib\site-packages (3.4.3)
# Requirement already satisfied: numpy>=1.16 in c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\lib\site-packages (from matplotlib) (1.21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: six in c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: scipy in c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\lib\site-packages (from scipy) (1.21.3)
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\t.nurgaliev\pycharmprojects\pythonproject\venv\scripts\python.exe -m pip install --upgrade pip' command.

# %%
from PIL import Image
from scipy import ndimage
from matplotlib import pyplot as plt
import numpy as np
import time
import cv2

# %%
original = np.array(Image.open('1.jpg'))
original_part = original[300:912, 500:1112]
Image.fromarray(original_part)
# Out:
# <PIL.Image.Image image mode=RGB size=612x612 at 0x19401434B50>

# %% [markdown]
# ### Реализация быстрого преобразования Хафа

# %%
def calc_sums(img, H, xmin, xmax):
    res = np.zeros([H, xmax-xmin])
    if xmax - xmin == 1:
        res[:, 0] = img[:, xmin]
    else:
        mid = (xmin + xmax) // 2
        ans1 = calc_sums(img, H, xmin, mid)
        ans2 = calc_sums(img, H, mid, xmax)
        for x in range(H):
            for shift in range(xmax-xmin):
                res[x, shift] = ans1[x, shift//2] + ans2[(x + shift//2 + shift%2) % H, shift//2]
    return res

def calc_FHT(img):
    """
    :param img: np.array[H, W], W=2^k
    :returns: FHT for img
    """
    H, W = img.shape[:2]
    
    return calc_sums(img, H, 0, W)

# %%
def reverse_bits(num, n):
    b = '{:0{width}b}'.format(num, width=max(n, len(bin(num)) - 2))
    b = b[:-n] + b[-n:][::-1]
    return int(b, 2)

# %%
def calc_sums(img, res, xmin, xmax):
    deg = int(np.log2(xmax - xmin))
    
    H = img.shape[0]
    if xmax - xmin == 1:
        res[:, 0] = img[:, xmin]
    else:
        mid = (xmin + xmax) // 2
        calc_sums(img, res, xmin, mid)
        calc_sums(img, res, mid, xmax)
        for x in range(H):
            for shift in range(xmax-xmin):
                res[x, xmin + reverse_bits(shift, deg)] = res[x, xmin + reverse_bits(shift//2, deg - 1)] + res[(x + shift//2 + shift%2) % H, mid + reverse_bits(shift//2, deg - 1)]
    return res

def calc_FHT(img):
    """
    :param img: np.array[H, W], W=2^k
    :returns: FHT for img
    """
    W = img.shape[1]
    res = np.zeros_like(img)
    return calc_sums(img, res, 0, W)

# %%
def crop_W_to_p2(img):
    H, W = img.shape[:2]
    W_cropped = 2 ** int(np.log2(W))
    return img[:, :W_cropped, ...]

# %%
def grayscale(x):
    R, G, B = x
    return 0.299 * R + 0.587 * G + 0.114 * B

def calc_intensity(img):
    return np.apply_along_axis(grayscale, -1, np.array(img, dtype=np.float32))

# %%
cropped = crop_W_to_p2(np.array(original_part, dtype=np.float32))
intensities = calc_intensity(cropped)

# %%
fht = calc_FHT(intensities)

plt.imshow(fht)
plt.show()

# %% [markdown]
# ### Поворот изображения

# %%
def clamp(x, smallest, largest): 
    return max(smallest, min(x, largest))

# %%
def calc_neighbours(x, lim):
    x1, x2 = int(np.floor(x)), int(np.ceil(x))
    if x1 == x2:
        if x2 == lim - 1:
            x1 -= 1
        else:
            x2 += 1
    return x1, x2

# %%
def inv_transform(x, y, beta, W, H, angle):
    x, y = x * beta, y * beta
    x, y = x - W * beta / 2, y - H * beta / 2 
    x, y = np.cos(angle) * x + np.sin(angle) * y, - np.sin(angle) * x + np.cos(angle) * y
    x, y = x + W / 2, y + H / 2
    if x > W - 1 or x < 0 or y > H - 1 or y < 0:
        x = clamp(x, 0, W - 1)
        y = clamp(y, 0, H - 1)
    return x, y

def interpolate(y, x, src, strategy):
    H, W = src.shape[:2]
    if strategy == "nn":
        y_nn, x_nn = round(y), round(x)
        return src[y_nn, x_nn, :]
    elif strategy == "bl":
        x1, x2 = calc_neighbours(x, W)
        y1, y2 = calc_neighbours(y, H)
        src11 = src[y1, x1, ...]
        src12 = src[y2, x1, ...]
        src21 = src[y1, x2, ...]
        src22 = src[y2, x2, ...]
        f1 = src11 + (x - x1) * (src21 - src11)
        f2 = src12 + (x - x1) * (src22 - src12)
        return f1 + (y - y1) * (f2 - f1)
        
def rotate(img, angle, strategy="nn"):
    H, W = img.shape[:2]
    # коэффициент растяжения
    beta = min(W / (W * np.cos(angle) + H * np.abs(np.sin(angle))), H / (W * np.abs(np.sin(angle)) + H * np.cos(angle)))
    result = np.zeros_like(img)
    
    for i in range(W):
        for j in range(H):
            x, y = inv_transform(i, j, beta, W, H, angle)
            result[j][i] = interpolate(y, x, img, strategy)
    return result

# %%
rotated = rotate(np.array(original_part, dtype=np.float32), - np.pi / 12, strategy = "bl")

# %%
Image.fromarray(np.array(rotated, dtype=np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=612x612 at 0x19404AE3160>

# %% [markdown]
# ### Восстановление геометрии

# %%
def autorotate(img, interpolate_strat="bl"):
    """
    :param img: np.array[H, W, C]
    :returns: img, rotated according to max intensity variance along line
    """
    cropped = crop_W_to_p2(np.array(original_part, dtype=np.float32))
    intensities = calc_intensity(cropped)
    fht = calc_FHT(intensities)
    
    alpha = np.argmax(np.apply_along_axis(np.std, 0, fht)) / fht.shape[1] * (np.pi / 4)
    rotated = rotate(np.array(img, dtype=np.float32), -alpha, strategy = interpolate_strat)
    return rotated

# %%
Image.fromarray(np.array(autorotate(original_part), dtype=np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=612x612 at 0x194062C9670>

# %%
Image.fromarray(np.array(autorotate(original), dtype=np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=1954x1100 at 0x194063819D0>
